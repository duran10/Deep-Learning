# %% [markdown]
# # Company Bankrupcy

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import Sequential    # import Sequential from tensorflow.keras
from tensorflow.keras.layers import Dense  # import Dense from tensorflow.keras.layers
from numpy.random import seed     # seed helps you to fix the randomness in the neural network.  
from tensorflow import keras
import keras_tuner as kt
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
import os, types
import seaborn as sns
from sklearn.decomposition import PCA

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# ### Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
#  8    After-tax net Interest Rate                              6819 non-null   float64
#  9    Non-industry income and expenditure/revenue              6819 non-null   float64
#  10   Continuous interest rate (after tax)                     6819 non-null   float64
#  11   Operating Expense Rate                                   6819 non-null   float64
#  12   Research and development expense rate                    6819 non-null   float64
#  13   Cash flow rate                                           6819 non-null   float64
#  14   Interest-bearing debt interest rate                      6819 non-null   float64
#  15   Tax rate (A)                                             6819 non-null   float64
#  16   Net Value Per Share (B)                                  6819 non-null   float64
#  17   Net Value Per Share (A)                                  6819 non-null   float64
#  18   Net Value Per Share (C)                                  6819 non-null   float64
#  19   Persistent EPS in the Last Four Seasons                  6819 non-null   float64
#  20   Cash Flow Per Share                                      6819 non-null   float64
#  21   Revenue Per Share (Yuan ¥)                               6819 non-null   float64
#  22   Operating Profit Per Share (Yuan ¥)                      6819 non-null   float64
#  23   Per Share Net profit before tax (Yuan ¥)                 6819 non-null   float64
#  24   Realized Sales Gross Profit Growth Rate                  6819 non-null   float64
#  25   Operating Profit Growth Rate                             6819 non-null   float64
#  26   After-tax Net Profit Growth Rate                         6819 non-null   float64
#  27   Regular Net Profit Growth Rate                           6819 non-null   float64
#  28   Continuous Net Profit Growth Rate                        6819 non-null   float64
#  29   Total Asset Growth Rate                                  6819 non-null   float64
#  30   Net Value Growth Rate                                    6819 non-null   float64
#  31   Total Asset Return Growth Rate Ratio                     6819 non-null   float64
#  32   Cash Reinvestment %                                      6819 non-null   float64
#  33   Current Ratio                                            6819 non-null   float64
#  34   Quick Ratio                                              6819 non-null   float64
#  35   Interest Expense Ratio                                   6819 non-null   float64
#  36   Total debt/Total net worth                               6819 non-null   float64
#  37   Debt ratio %                                             6819 non-null   float64
#  38   Net worth/Assets                                         6819 non-null   float64
#  39   Long-term fund suitability ratio (A)                     6819 non-null   float64
#  40   Borrowing dependency                                     6819 non-null   float64
#  41   Contingent liabilities/Net worth                         6819 non-null   float64
#  42   Operating profit/Paid-in capital                         6819 non-null   float64
#  43   Net profit before tax/Paid-in capital                    6819 non-null   float64
#  44   Inventory and accounts receivable/Net value              6819 non-null   float64
#  45   Total Asset Turnover                                     6819 non-null   float64
#  46   Accounts Receivable Turnover                             6819 non-null   float64
#  47   Average Collection Days                                  6819 non-null   float64
#  48   Inventory Turnover Rate (times)                          6819 non-null   float64
#  49   Fixed Assets Turnover Frequency                          6819 non-null   float64
#  50   Net Worth Turnover Rate (times)                          6819 non-null   float64
#  51   Revenue per person                                       6819 non-null   float64
#  52   Operating profit per person                              6819 non-null   float64
#  53   Allocation rate per person                               6819 non-null   float64
#  54   Working Capital to Total Assets                          6819 non-null   float64
#  55   Quick Assets/Total Assets                                6819 non-null   float64
#  56   Current Assets/Total Assets                              6819 non-null   float64
#  57   Cash/Total Assets                                        6819 non-null   float64
#  58   Quick Assets/Current Liability                           6819 non-null   float64
#  59   Cash/Current Liability                                   6819 non-null   float64
#  60   Current Liability to Assets                              6819 non-null   float64
#  61   Operating Funds to Liability                             6819 non-null   float64
#  62   Inventory/Working Capital                                6819 non-null   float64
#  63   Inventory/Current Liability                              6819 non-null   float64
#  64   Current Liabilities/Liability                            6819 non-null   float64
#  65   Working Capital/Equity                                   6819 non-null   float64
#  66   Current Liabilities/Equity                               6819 non-null   float64
#  67   Long-term Liability to Current Assets                    6819 non-null   float64
#  68   Retained Earnings to Total Assets                        6819 non-null   float64
#  69   Total income/Total expense                               6819 non-null   float64
#  70   Total expense/Assets                                     6819 non-null   float64
#  71   Current Asset Turnover Rate                              6819 non-null   float64
#  72   Quick Asset Turnover Rate                                6819 non-null   float64
#  73   Working capitcal Turnover Rate                           6819 non-null   float64
#  74   Cash Turnover Rate                                       6819 non-null   float64
#  75   Cash Flow to Sales                                       6819 non-null   float64
#  76   Fixed Assets to Assets                                   6819 non-null   float64
#  77   Current Liability to Liability                           6819 non-null   float64
#  78   Current Liability to Equity                              6819 non-null   float64
#  79   Equity to Long-term Liability                            6819 non-null   float64
#  80   Cash Flow to Total Assets                                6819 non-null   float64
#  81   Cash Flow to Liability                                   6819 non-null   float64
#  82   CFO to Assets                                            6819 non-null   float64
#  83   Cash Flow to Equity                                      6819 non-null   float64
#  84   Current Liability to Current Assets                      6819 non-null   float64
#  85   Liability-Assets Flag                                    6819 non-null   int64
#  86   Net Income to Total Assets                               6819 non-null   float64
#  87   Total assets to GNP price                                6819 non-null   float64
#  88   No-credit Interval                                       6819 non-null   float64
#  89   Gross Profit to Sales                                    6819 non-null   float64
#  90   Net Income to Stockholder's Equity                       6819 non-null   float64
#  91   Liability to Equity                                      6819 non-null   float64
#  92   Degree of Financial Leverage (DFL)                       6819 non-null   float64
#  93   Interest Coverage Ratio (Interest expense to EBIT)       6819 non-null   float64
#  94   Net Income Flag                                          6819 non-null   int64
#  95   Equity to Liability                                      6819 non-null   float64
# dtypes: float64(93), int64(3)
# memory usage: 5.0 MB

# %%
# plot missing values
plt.style.use('seaborn')
plt.figure(figsize = (10,5))
sns.heatmap(df.isnull(), yticklabels = False, cmap = 'plasma')
plt.title('Null Values in Data Frame')
# Out:
# Text(0.5, 1.0, 'Null Values in Data Frame')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.columns= [i.lower().strip().replace(' ', '_') for i in df.columns]
df.columns
# Out:
# Index(['bankrupt?', 'roa(c)_before_interest_and_depreciation_before_interest',
#        'roa(a)_before_interest_and_%_after_tax',
#        'roa(b)_before_interest_and_depreciation_after_tax',
#        'operating_gross_margin', 'realized_sales_gross_margin',
#        'operating_profit_rate', 'pre-tax_net_interest_rate',
#        'after-tax_net_interest_rate',
#        'non-industry_income_and_expenditure/revenue',
#        'continuous_interest_rate_(after_tax)', 'operating_expense_rate',
#        'research_and_development_expense_rate', 'cash_flow_rate',
#        'interest-bearing_debt_interest_rate', 'tax_rate_(a)',
#        'net_value_per_share_(b)', 'net_value_per_share_(a)',
#        'net_value_per_share_(c)', 'persistent_eps_in_the_last_four_seasons',
#        'cash_flow_per_share', 'revenue_per_share_(yuan_¥)',
#        'operating_profit_per_share_(yuan_¥)',
#        'per_share_net_profit_before_tax_(yuan_¥)',
#        'realized_sales_gross_profit_growth_rate',
#        'operating_profit_growth_rate', 'after-tax_net_profit_growth_rate',
#        'regular_net_profit_growth_rate', 'continuous_net_profit_growth_rate',
#        'total_asset_growth_rate', 'net_value_growth_rate',
#        'total_asset_return_growth_rate_ratio', 'cash_reinvestment_%',
#        'current_ratio', 'quick_ratio', 'interest_expense_ratio',
#        'total_debt/total_net_worth', 'debt_ratio_%', 'net_worth/assets',
#        'long-term_fund_suitability_ratio_(a)', 'borrowing_dependency',
#        'contingent_liabilities/net_worth', 'operating_profit/paid-in_capital',
#        'net_profit_before_tax/paid-in_capital',
#        'inventory_and_accounts_receivable/net_value', 'total_asset_turnover',
#        'accounts_receivable_turnover', 'average_collection_days',
#        'inventory_turnover_rate_(times)', 'fixed_assets_turnover_frequency',
#        'net_worth_turnover_rate_(times)', 'revenue_per_person',
#        'operating_profit_per_person', 'allocation_rate_per_person',
#        'working_capital_to_total_assets', 'quick_assets/total_assets',
#        'current_assets/total_assets', 'cash/total_assets',
#        'quick_assets/current_liability', 'cash/current_liability',
#        'current_liability_to_assets', 'operating_funds_to_liability',
#        'inventory/working_capital', 'inventory/current_liability',
#        'current_liabilities/liability', 'working_capital/equity',
#        'current_liabilities/equity', 'long-term_liability_to_current_assets',
#        'retained_earnings_to_total_assets', 'total_income/total_expense',
#        'total_expense/assets', 'current_asset_turnover_rate',
#        'quick_asset_turnover_rate', 'working_capitcal_turnover_rate',
#        'cash_turnover_rate', 'cash_flow_to_sales', 'fixed_assets_to_assets',
#        'current_liability_to_liability', 'current_liability_to_equity',
#        'equity_to_long-term_liability', 'cash_flow_to_total_assets',
#        'cash_flow_to_liability', 'cfo_to_assets', 'cash_flow_to_equity',
#        'current_liability_to_current_assets', 'liability-assets_flag',
#        'net_income_to_total_assets', 'total_assets_to_gnp_price',
#        'no-credit_interval', 'gross_profit_to_sales',
#        'net_income_to_stockholder's_equity', 'liability_to_equity',
#        'degree_of_financial_leverage_(dfl)',
#        'interest_coverage_ratio_(interest_expense_to_ebit)', 'net_income_flag',
#        'equity_to_liability'],
#       dtype='object')

# %%
sns.set_style('darkgrid')

xi = df['bankrupt?'].unique()
yi = df['bankrupt?'].value_counts(normalize = True).sort_values(ascending = True)

sns.barplot(xi, yi)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * fractional columns: The columns that contain the values between 0 and 1 .
# * non-fractional columns : They are columns that contain different values.

# %%
##  separate between fractional columns and non-fraction columns
def get_fraction_valued_columns(df):
    my_columns  = []
    for col in df.columns:
        if (df[col].max()<=1) & (df[col].min() >= 0):
            my_columns.append(col)
    return(my_columns)

fractional_columns = get_fraction_valued_columns(df=df.drop(['bankrupt?'],axis=1))
non_fractional_columns = df.drop(['bankrupt?'],axis=1).columns.difference(fractional_columns)
print("# Fractional  Columns number are:",len(fractional_columns),"\t","# Non  Fractional Columns number are:", len(non_fractional_columns))
# Out:
# # Fractional  Columns number are: 71 	 # Non  Fractional Columns number are: 24

# %%
df[non_fractional_columns].describe().T
# Out:
#                                         count          mean           std  \
# accounts_receivable_turnover           6819.0  1.278971e+07  2.782598e+08
# allocation_rate_per_person             6819.0  1.125579e+07  2.945063e+08
# average_collection_days                6819.0  9.826221e+06  2.563589e+08
# cash/current_liability                 6819.0  3.715999e+07  5.103509e+08
# cash_turnover_rate                     6819.0  2.471977e+09  2.938623e+09
# current_asset_turnover_rate            6819.0  1.195856e+09  2.821161e+09
# current_ratio                          6819.0  4.032850e+05  3.330216e+07
# fixed_assets_to_assets                 6819.0  1.220121e+06  1.007542e+08
# fixed_assets_turnover_frequency        6819.0  1.008596e+09  2.477557e+09
# interest-bearing_debt_interest_rate    6819.0  1.644801e+07  1.082750e+08
# inventory/current_liability            6819.0  5.580680e+07  5.820516e+08
# inventory_turnover_rate_(times)        6819.0  2.149106e+09  3.247967e+09
# long-term_liability_to_current_assets  6819.0  5.416004e+07  5.702706e+08
# net_value_growth_rate                  6819.0  1.566212e+06  1.141594e+08
# operating_expense_rate                 6819.0  1.995347e+09  3.237684e+09
# quick_asset_turnover_rate              6819.0  2.163735e+09  3.374944e+09
# quick_assets/current_liability         6819.0  3.592902e+06  1.716209e+08
# quick_ratio                            6819.0  8.376595e+06  2.446847e+08
# research_and_development_expense_rate  6819.0  1.950427e+09  2.598292e+09
# revenue_per_person                     6819.0  2.325854e+06  1.366327e+08
# revenue_per_share_(yuan_¥)             6819.0  1.328641e+06  5.170709e+07
# total_asset_growth_rate                6819.0  5.508097e+09  2.897718e+09
# total_assets_to_gnp_price              6819.0  1.862942e+07  3.764501e+08
# total_debt/total_net_worth             6819.0  4.416337e+06  1.684069e+08
#
#                                        min           25%           50%  \
# accounts_receivable_turnover           0.0  7.101336e-04  9.678107e-04
# allocation_rate_per_person             0.0  4.120529e-03  7.844373e-03
# average_collection_days                0.0  4.386530e-03  6.572537e-03
# cash/current_liability                 0.0  1.973008e-03  4.903886e-03
# cash_turnover_rate                     0.0  2.735337e-04  1.080000e+09
# current_asset_turnover_rate            0.0  1.456236e-04  1.987816e-04
# current_ratio                          0.0  7.555047e-03  1.058717e-02
# fixed_assets_to_assets                 0.0  8.536037e-02  1.968810e-01
# fixed_assets_turnover_frequency        0.0  2.330013e-04  5.930942e-04
# interest-bearing_debt_interest_rate    0.0  2.030203e-04  3.210321e-04
# inventory/current_liability            0.0  3.163148e-03  6.497335e-03
# inventory_turnover_rate_(times)        0.0  1.728256e-04  7.646743e-04
# long-term_liability_to_current_assets  0.0  0.000000e+00  1.974619e-03
# net_value_growth_rate                  0.0  4.409689e-04  4.619555e-04
# operating_expense_rate                 0.0  1.566874e-04  2.777589e-04
# quick_asset_turnover_rate              0.0  1.417149e-04  2.247728e-04
# quick_assets/current_liability         0.0  5.239776e-03  7.908898e-03
# quick_ratio                            0.0  4.725903e-03  7.412472e-03
# research_and_development_expense_rate  0.0  1.281880e-04  5.090000e+08
# revenue_per_person                     0.0  1.043285e-02  1.861551e-02
# revenue_per_share_(yuan_¥)             0.0  1.563138e-02  2.737571e-02
# total_asset_growth_rate                0.0  4.860000e+09  6.400000e+09
# total_assets_to_gnp_price              0.0  9.036205e-04  2.085213e-03
# total_debt/total_net_worth             0.0  3.007049e-03  5.546284e-03
#
#                                                 75%           max
# accounts_receivable_turnover           1.454759e-03  9.740000e+09
# allocation_rate_per_person             1.502031e-02  9.570000e+09
# average_collection_days                8.972876e-03  9.730000e+09
# cash/current_liability                 1.280557e-02  9.650000e+09
# cash_turnover_rate                     4.510000e+09  1.000000e+10
# current_asset_turnover_rate            4.525945e-04  1.000000e+10
# current_ratio                          1.626953e-02  2.750000e+09
# fixed_assets_to_assets                 3.722000e-01  8.320000e+09
# fixed_assets_turnover_frequency        3.652371e-03  9.990000e+09
# interest-bearing_debt_interest_rate    5.325533e-04  9.900000e+08
# inventory/current_liability            1.114677e-02  9.910000e+09
# inventory_turnover_rate_(times)        4.620000e+09  9.990000e+09
# long-term_liability_to_current_assets  9.005946e-03  9.540000e+09
# net_value_growth_rate                  4.993621e-04  9.330000e+09
# operating_expense_rate                 4.145000e+09  9.990000e+09
# quick_asset_turnover_rate              4.900000e+09  1.000000e+10
# quick_assets/current_liability         1.295091e-02  8.820000e+09
# quick_ratio                            1.224911e-02  9.230000e+09
# research_and_development_expense_rate  3.450000e+09  9.980000e+09
# revenue_per_person                     3.585477e-02  8.810000e+09
# revenue_per_share_(yuan_¥)             4.635722e-02  3.020000e+09
# total_asset_growth_rate                7.390000e+09  9.990000e+09
# total_assets_to_gnp_price              5.269777e-03  9.820000e+09
# total_debt/total_net_worth             9.273293e-03  9.940000e+09

# %%
plt.figure(figsize = (20,50))
ax =sns.boxplot(data = df[non_fractional_columns], orient="h")
ax.set_title('Bank Data Boxplots', fontsize = 18)
ax.set(xscale="log")
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
y = df['bankrupt?']
X = df.drop(columns=['bankrupt?'])

# %%
scaler = StandardScaler()
X_prepared = scaler.fit_transform(X)
X_prepared
# Out:
# array([[-2.21790935, -2.04579778, -2.400361  , ..., -0.09897786,
#          0.        , -0.62206729],
#        [-0.67382819, -0.31106786, -0.59844969, ...,  0.3645587 ,
#          0.        , -0.53557337],
#        [-1.30367191, -0.90841978, -1.3199096 , ..., -0.125015  ,
#          0.        , -0.62195984],
#        ...,
#        [-0.53484482, -0.37919423, -0.53499599, ..., -0.01510132,
#          0.        ,  1.0012064 ],
#        [ 0.01787518,  0.01959426,  0.00740279, ..., -0.00427044,
#          0.        , -0.07136384],
#        [-0.19983866,  0.17495561, -0.06561243, ..., -0.01445435,
#          0.        ,  3.72572884]])

# %%
pca=PCA(0.70)

# %%
X_pca = pca.fit_transform(X_prepared)

# %%
X_pca.shape
# Out:
# (6819, 25)

# %%
pc1 = X_pca[:,0]
pc2 = X_pca[:,1]

#Plot principal components
plt.figure(figsize=(10,10))

colour = ['#ff2121' if y == 1 else '#2176ff' for y in df['bankrupt?']]
plt.scatter(pc1,pc2 ,c=colour,edgecolors='#000000')
plt.yticks(size=12)
plt.xticks(size=12)
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0, 0.5, 'PC2')

# %%
explained_variance = np.var(X_pca, axis=0)
var = explained_variance[0:10] #percentage of variance explained
labels = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10']

plt.figure(figsize=(15,7))
plt.bar(labels,var,)
plt.xlabel('Pricipal Component', fontsize=18)
plt.ylabel('Proportion of Variance Explained', fontsize=18)

print(var[0]+ var[1])
# Out:
# 19.327086136848784

# %%
X_train_prepared, X_test_prepared, y_train, y_test = train_test_split(X_pca, y, random_state=42, test_size=0.2)

# %%
#scaler = StandardScaler()
#models = scaler.fit(X_train)
#X_train_prepared = models.transform(X_train)
#X_test_prepared = models.transform(X_test)

# %%
X_train_prepared
# Out:
# array([[-1.1406076 ,  0.48015575,  0.75992644, ...,  0.24128623,
#          0.0206565 ,  0.06467048],
#        [-0.26026721,  0.57248676, -2.34804866, ..., -0.50047302,
#         -0.10400443, -0.02314276],
#        [ 0.9000508 , -0.71469465,  1.73295497, ..., -0.46543282,
#         -0.17104377, -0.30912947],
#        ...,
#        [-0.11747424,  0.54138609, -1.87749917, ..., -0.40841739,
#         -0.26316487,  0.02210903],
#        [ 4.05229548,  0.49511838, -0.21781263, ..., -2.06337521,
#         -0.51085651, -0.29193724],
#        [ 5.60492545,  1.18713603, -0.17915888, ..., -0.39307339,
#         -0.61361865,  0.05409242]])

# %%
X_train_prepared.shape
# Out:
# (5455, 25)

# %%
X_test_prepared.shape
# Out:
# (1364, 25)

# %% [markdown]
# ### Model

# %%
from keras_tuner import HyperModel
class HyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape
    def build(self, hp):
        model = Sequential()
        model.add(
            layers.Dense(
                units=hp.Int('units', 100, 460, 8),
                activation='relu',
                input_shape=input_shape
            )
        )
        
        model.add(
            layers.Dropout(
                hp.Float(
                    'dropout',
                    min_value=0.0,
                    max_value=0.1,
                    default=0.005,
                    step=0.01)
            )
        )
        
        
        model.add(
            layers.Dense(
                units=hp.Int('units', 100, 460, 8),
                activation='relu'
            )
        )

        model.add(
            layers.Dropout(
                hp.Float(
                    'dropout',
                    min_value=0.0,
                    max_value=0.1,
                    default=0.005,
                    step=0.01)
            )
        )
        
                
        model.add(layers.Dense(1, activation= 'sigmoid'))
        
        hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
        model.compile(loss='binary_crossentropy',
                optimizer=tf.keras.optimizers.SGD(learning_rate=hp_learning_rate), metrics=['accuracy'])
        
        
        return model

# %%
input_shape = (X_train_prepared.shape[1],)
hypermodel = HyperModel(input_shape)

# %%
from keras_tuner import BayesianOptimization

tuner_bo = BayesianOptimization(
            hypermodel,
            objective='val_loss',
            max_trials=30,
            seed=42,
            executions_per_trial=2
        )
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
tuner_bo.search(X_train_prepared, y_train, epochs=100, validation_split=0.2, verbose=0, callbacks=[stop_early])
best_model = tuner_bo.get_best_models(num_models=1)[0]
evaluation = best_model.evaluate(X_test_prepared, y_test)
evaluation
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json
# INFO:tensorflow:Oracle triggered exit
# 43/43 [==============================] - 1s 5ms/step - loss: 0.1803 - accuracy: 0.9611
# [0.18030759692192078, 0.9611436724662781]

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 460)               11960
#
#  dropout (Dropout)           (None, 460)               0
#
#  dense_1 (Dense)             (None, 460)               212060
#
#  dropout_1 (Dropout)         (None, 460)               0
#
#  dense_2 (Dense)             (None, 1)                 461
#
# =================================================================
# Total params: 224,481
# Trainable params: 224,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Get the optimal hyperparameters
best_hps=tuner_bo.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in th densely-connected
layers is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in th densely-connected
# layers is 460 and the optimal learning rate for the optimizer
# is 0.01.

# %%
best_hps.values
# Out:
# {'dropout': 0.06, 'learning_rate': 0.01, 'units': 460}

# %%
history = best_model.fit(X_train_prepared, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 137/137 [==============================] - 3s 11ms/step - loss: 0.0610 - accuracy: 0.9780 - val_loss: 0.0990 - val_accuracy: 0.9670
# Epoch 2/100
# 137/137 [==============================] - 1s 11ms/step - loss: 0.0617 - accuracy: 0.9773 - val_loss: 0.0990 - val_accuracy: 0.9670
# Epoch 3/100
# 137/137 [==============================] - 2s 12ms/step - loss: 0.0604 - accuracy: 0.9778 - val_loss: 0.0977 - val_accuracy: 0.9688
# Epoch 4/100
# 137/137 [==============================] - 1s 11ms/step - loss: 0.0618 - accuracy: 0.9775 - val_loss: 0.0983 - val_accuracy: 0.9670
# Epoch 5/100
# 137/137 [==============================] - 1s 11ms/step - loss: 0.0610 - accuracy: 0.9782 - val_loss: 0.0992 - val_accuracy: 0.9670
# Epoch 6/100
# 137/137 [==============================] - 2s 11ms/step - loss: 0.0605 - accuracy: 0.9780 - val_loss: 0.1001 - val_accuracy: 0.9670
# Epoch 7/100
# 137/137 [==============================] - 2s 11ms/step - loss: 0.0610 - accuracy: 0.9780 - val_loss: 0.0994 - val_accuracy: 0.9670
# Epoch 8/100
# 137/137 [==============================] - 2s 12ms/step - loss: 0.0605 - accuracy: 0.9775 - val_loss: 0.0994 - val_accuracy: 0.9670
# Epoch 9/100
# 137/137 [==============================] - 1s 9ms/step - loss: 0.0605 - accuracy: 0.9782 - val_loss: 0.1004 - val_accuracy: 0.9670
# Epoch 10/100
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0599 - accuracy: 0.9785 - val_loss: 0.0981 - val_accuracy: 0.9670
# Epoch 11/100
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0602 - accuracy: 0.9780 - val_loss: 0.0986 - val_accuracy: 0.9679
# Epoch 12/100
# 137/137 [==============================] - 2s 12ms/step - loss: 0.0592 - accuracy: 0.9794 - val_loss: 0.0986 - val_accuracy: 0.9670
# Epoch 13/100
# 137/137 [==============================] - 1s 11ms/step - loss: 0.0597 - accuracy: 0.9771 - val_loss: 0.0976 - val_accuracy: 0.9670
# Epoch 14/100
# 137/137 [==============================] - 1s 9ms/step - loss: 0.0596 - accuracy: 0.9785 - val_loss: 0.0981 - val_accuracy: 0.9670
# Epoch 15/100
# 137/137 [==============================] - 1s 9ms/step - loss: 0.0589 - accuracy: 0.9789 - val_loss: 0.0976 - val_accuracy: 0.9679
# Epoch 16/100
# 137/137 [==============================] - 1s 9ms/step - loss: 0.0597 - accuracy: 0.9778 - val_loss: 0.1038 - val_accuracy: 0.9661
# Epoch 17/100
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0584 - accuracy: 0.9796 - val_loss: 0.0977 - val_accuracy: 0.9670
# Epoch 18/100
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0584 - accuracy: 0.9785 - val_loss: 0.1000 - val_accuracy: 0.9670
# Epoch 19/100
# 137/137 [==============================] - 1s 8ms/step - loss: 0.0583 - accuracy: 0.9782 - val_loss: 0.0973 - val_accuracy: 0.9670
# Epoch 20/100
# 137/137 [==============================] - 1s 10ms/step - loss: 0.0596 - accuracy: 0.9778 - val_loss: 0.0980 - val_accuracy: 0.9679
# Epoch 21/100
# 137/137 [==============================] - 1s 8ms/step - loss: 0.0568 - accuracy: 0.9794 - val_loss: 0.0977 - val_accuracy: 0.9670
# Epoch 22/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0591 - accuracy: 0.9787 - val_loss: 0.1006 - val_accuracy: 0.9670
# Epoch 23/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0575 - accuracy: 0.9791 - val_loss: 0.1010 - val_accuracy: 0.9661
# Epoch 24/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0580 - accuracy: 0.9785 - val_loss: 0.0988 - val_accuracy: 0.9670
# Epoch 25/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0571 - accuracy: 0.9785 - val_loss: 0.0999 - val_accuracy: 0.9670
# Epoch 26/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0577 - accuracy: 0.9780 - val_loss: 0.0970 - val_accuracy: 0.9679
# Epoch 27/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0582 - accuracy: 0.9794 - val_loss: 0.0984 - val_accuracy: 0.9661
# Epoch 28/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0561 - accuracy: 0.9810 - val_loss: 0.0996 - val_accuracy: 0.9670
# Epoch 29/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0571 - accuracy: 0.9789 - val_loss: 0.0980 - val_accuracy: 0.9670
# Epoch 30/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0576 - accuracy: 0.9794 - val_loss: 0.1005 - val_accuracy: 0.9670
# Epoch 31/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0577 - accuracy: 0.9789 - val_loss: 0.0986 - val_accuracy: 0.9661
# Epoch 32/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0571 - accuracy: 0.9794 - val_loss: 0.0980 - val_accuracy: 0.9670
# Epoch 33/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0566 - accuracy: 0.9794 - val_loss: 0.1013 - val_accuracy: 0.9670
# Epoch 34/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0556 - accuracy: 0.9801 - val_loss: 0.0971 - val_accuracy: 0.9679
# Epoch 35/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0560 - accuracy: 0.9796 - val_loss: 0.0973 - val_accuracy: 0.9670
# Epoch 36/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0575 - accuracy: 0.9785 - val_loss: 0.0972 - val_accuracy: 0.9679
# Epoch 37/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0570 - accuracy: 0.9778 - val_loss: 0.0969 - val_accuracy: 0.9661
# Epoch 38/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0562 - accuracy: 0.9791 - val_loss: 0.0976 - val_accuracy: 0.9679
# Epoch 39/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0550 - accuracy: 0.9805 - val_loss: 0.0992 - val_accuracy: 0.9679
# Epoch 40/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0543 - accuracy: 0.9805 - val_loss: 0.0984 - val_accuracy: 0.9661
# Epoch 41/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0557 - accuracy: 0.9796 - val_loss: 0.1003 - val_accuracy: 0.9679
# Epoch 42/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0541 - accuracy: 0.9794 - val_loss: 0.0973 - val_accuracy: 0.9661
# Epoch 43/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0543 - accuracy: 0.9801 - val_loss: 0.0980 - val_accuracy: 0.9661
# Epoch 44/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0549 - accuracy: 0.9801 - val_loss: 0.0991 - val_accuracy: 0.9661
# Epoch 45/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0546 - accuracy: 0.9798 - val_loss: 0.0971 - val_accuracy: 0.9661
# Epoch 46/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0542 - accuracy: 0.9785 - val_loss: 0.0993 - val_accuracy: 0.9661
# Epoch 47/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0541 - accuracy: 0.9803 - val_loss: 0.0975 - val_accuracy: 0.9661
# Epoch 48/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0540 - accuracy: 0.9808 - val_loss: 0.0978 - val_accuracy: 0.9661
# Epoch 49/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0546 - accuracy: 0.9812 - val_loss: 0.0980 - val_accuracy: 0.9670
# Epoch 50/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0537 - accuracy: 0.9796 - val_loss: 0.0993 - val_accuracy: 0.9670
# Epoch 51/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0532 - accuracy: 0.9810 - val_loss: 0.0999 - val_accuracy: 0.9661
# Epoch 52/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0538 - accuracy: 0.9805 - val_loss: 0.0987 - val_accuracy: 0.9661
# Epoch 53/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0525 - accuracy: 0.9805 - val_loss: 0.0973 - val_accuracy: 0.9661
# Epoch 54/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0532 - accuracy: 0.9805 - val_loss: 0.0967 - val_accuracy: 0.9661
# Epoch 55/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0528 - accuracy: 0.9803 - val_loss: 0.0972 - val_accuracy: 0.9652
# Epoch 56/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0529 - accuracy: 0.9805 - val_loss: 0.0980 - val_accuracy: 0.9652
# Epoch 57/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0529 - accuracy: 0.9794 - val_loss: 0.0997 - val_accuracy: 0.9652
# Epoch 58/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0527 - accuracy: 0.9803 - val_loss: 0.0981 - val_accuracy: 0.9652
# Epoch 59/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0526 - accuracy: 0.9810 - val_loss: 0.1007 - val_accuracy: 0.9661
# Epoch 60/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0527 - accuracy: 0.9803 - val_loss: 0.0975 - val_accuracy: 0.9661
# Epoch 61/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0519 - accuracy: 0.9812 - val_loss: 0.0969 - val_accuracy: 0.9633
# Epoch 62/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0512 - accuracy: 0.9817 - val_loss: 0.1018 - val_accuracy: 0.9670
# Epoch 63/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0519 - accuracy: 0.9808 - val_loss: 0.0996 - val_accuracy: 0.9652
# Epoch 64/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0517 - accuracy: 0.9814 - val_loss: 0.0984 - val_accuracy: 0.9643
# Epoch 65/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0509 - accuracy: 0.9814 - val_loss: 0.0987 - val_accuracy: 0.9643
# Epoch 66/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0517 - accuracy: 0.9808 - val_loss: 0.0971 - val_accuracy: 0.9670
# Epoch 67/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0516 - accuracy: 0.9798 - val_loss: 0.1001 - val_accuracy: 0.9652
# Epoch 68/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0516 - accuracy: 0.9798 - val_loss: 0.0981 - val_accuracy: 0.9652
# Epoch 69/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0506 - accuracy: 0.9808 - val_loss: 0.1003 - val_accuracy: 0.9661
# Epoch 70/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0497 - accuracy: 0.9814 - val_loss: 0.0972 - val_accuracy: 0.9652
# Epoch 71/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0504 - accuracy: 0.9808 - val_loss: 0.0986 - val_accuracy: 0.9643
# Epoch 72/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0508 - accuracy: 0.9805 - val_loss: 0.1015 - val_accuracy: 0.9661
# Epoch 73/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0499 - accuracy: 0.9814 - val_loss: 0.0992 - val_accuracy: 0.9670
# Epoch 74/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0501 - accuracy: 0.9821 - val_loss: 0.0983 - val_accuracy: 0.9652
# Epoch 75/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0489 - accuracy: 0.9824 - val_loss: 0.1001 - val_accuracy: 0.9643
# Epoch 76/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0503 - accuracy: 0.9803 - val_loss: 0.1001 - val_accuracy: 0.9652
# Epoch 77/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0506 - accuracy: 0.9812 - val_loss: 0.1003 - val_accuracy: 0.9643
# Epoch 78/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0489 - accuracy: 0.9817 - val_loss: 0.1002 - val_accuracy: 0.9661
# Epoch 79/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0501 - accuracy: 0.9824 - val_loss: 0.1008 - val_accuracy: 0.9652
# Epoch 80/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0481 - accuracy: 0.9824 - val_loss: 0.0998 - val_accuracy: 0.9643
# Epoch 81/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0484 - accuracy: 0.9828 - val_loss: 0.1019 - val_accuracy: 0.9652
# Epoch 82/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0486 - accuracy: 0.9824 - val_loss: 0.0981 - val_accuracy: 0.9652
# Epoch 83/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0486 - accuracy: 0.9830 - val_loss: 0.0988 - val_accuracy: 0.9661
# Epoch 84/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0493 - accuracy: 0.9817 - val_loss: 0.0977 - val_accuracy: 0.9670
# Epoch 85/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0485 - accuracy: 0.9833 - val_loss: 0.1021 - val_accuracy: 0.9670
# Epoch 86/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0486 - accuracy: 0.9814 - val_loss: 0.1002 - val_accuracy: 0.9643
# Epoch 87/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0484 - accuracy: 0.9821 - val_loss: 0.1025 - val_accuracy: 0.9652
# Epoch 88/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0485 - accuracy: 0.9819 - val_loss: 0.1003 - val_accuracy: 0.9661
# Epoch 89/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0491 - accuracy: 0.9819 - val_loss: 0.0992 - val_accuracy: 0.9661
# Epoch 90/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0487 - accuracy: 0.9821 - val_loss: 0.1023 - val_accuracy: 0.9670
# Epoch 91/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0483 - accuracy: 0.9814 - val_loss: 0.0999 - val_accuracy: 0.9670
# Epoch 92/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0476 - accuracy: 0.9817 - val_loss: 0.0985 - val_accuracy: 0.9670
# Epoch 93/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0470 - accuracy: 0.9812 - val_loss: 0.0979 - val_accuracy: 0.9661
# Epoch 94/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0475 - accuracy: 0.9830 - val_loss: 0.0991 - val_accuracy: 0.9643
# Epoch 95/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0474 - accuracy: 0.9817 - val_loss: 0.0991 - val_accuracy: 0.9652
# Epoch 96/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0476 - accuracy: 0.9830 - val_loss: 0.0994 - val_accuracy: 0.9652
# Epoch 97/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0459 - accuracy: 0.9830 - val_loss: 0.1014 - val_accuracy: 0.9643
# Epoch 98/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0465 - accuracy: 0.9833 - val_loss: 0.1009 - val_accuracy: 0.9661
# Epoch 99/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0468 - accuracy: 0.9835 - val_loss: 0.1013 - val_accuracy: 0.9652
# Epoch 100/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0458 - accuracy: 0.9826 - val_loss: 0.0982 - val_accuracy: 0.9670

# %%
val_loss_per_epoch = history.history['val_loss']
best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 54

# %%
history = best_model.fit(X_train_prepared, y_train, epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/54
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0459 - accuracy: 0.9837 - val_loss: 0.0999 - val_accuracy: 0.9643
# Epoch 2/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0444 - accuracy: 0.9842 - val_loss: 0.1008 - val_accuracy: 0.9643
# Epoch 3/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0455 - accuracy: 0.9824 - val_loss: 0.1001 - val_accuracy: 0.9643
# Epoch 4/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0458 - accuracy: 0.9828 - val_loss: 0.1011 - val_accuracy: 0.9661
# Epoch 5/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0466 - accuracy: 0.9824 - val_loss: 0.1023 - val_accuracy: 0.9661
# Epoch 6/54
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0445 - accuracy: 0.9833 - val_loss: 0.1043 - val_accuracy: 0.9652
# Epoch 7/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0459 - accuracy: 0.9826 - val_loss: 0.0997 - val_accuracy: 0.9670
# Epoch 8/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0450 - accuracy: 0.9826 - val_loss: 0.1006 - val_accuracy: 0.9670
# Epoch 9/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0461 - accuracy: 0.9828 - val_loss: 0.1002 - val_accuracy: 0.9643
# Epoch 10/54
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0452 - accuracy: 0.9828 - val_loss: 0.0994 - val_accuracy: 0.9652
# Epoch 11/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0445 - accuracy: 0.9833 - val_loss: 0.1010 - val_accuracy: 0.9661
# Epoch 12/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0438 - accuracy: 0.9842 - val_loss: 0.1022 - val_accuracy: 0.9661
# Epoch 13/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0441 - accuracy: 0.9835 - val_loss: 0.0991 - val_accuracy: 0.9661
# Epoch 14/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0448 - accuracy: 0.9837 - val_loss: 0.0988 - val_accuracy: 0.9661
# Epoch 15/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0440 - accuracy: 0.9826 - val_loss: 0.0988 - val_accuracy: 0.9670
# Epoch 16/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0435 - accuracy: 0.9846 - val_loss: 0.1023 - val_accuracy: 0.9670
# Epoch 17/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0431 - accuracy: 0.9842 - val_loss: 0.1002 - val_accuracy: 0.9643
# Epoch 18/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0435 - accuracy: 0.9837 - val_loss: 0.0984 - val_accuracy: 0.9661
# Epoch 19/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0452 - accuracy: 0.9828 - val_loss: 0.1026 - val_accuracy: 0.9661
# Epoch 20/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0433 - accuracy: 0.9846 - val_loss: 0.1008 - val_accuracy: 0.9652
# Epoch 21/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0428 - accuracy: 0.9849 - val_loss: 0.1010 - val_accuracy: 0.9643
# Epoch 22/54
# 137/137 [==============================] - 1s 11ms/step - loss: 0.0439 - accuracy: 0.9821 - val_loss: 0.0991 - val_accuracy: 0.9670
# Epoch 23/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0432 - accuracy: 0.9844 - val_loss: 0.1006 - val_accuracy: 0.9643
# Epoch 24/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0425 - accuracy: 0.9846 - val_loss: 0.0989 - val_accuracy: 0.9670
# Epoch 25/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0416 - accuracy: 0.9853 - val_loss: 0.1001 - val_accuracy: 0.9643
# Epoch 26/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0430 - accuracy: 0.9833 - val_loss: 0.1016 - val_accuracy: 0.9643
# Epoch 27/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0406 - accuracy: 0.9837 - val_loss: 0.0999 - val_accuracy: 0.9652
# Epoch 28/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0423 - accuracy: 0.9840 - val_loss: 0.1016 - val_accuracy: 0.9643
# Epoch 29/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0426 - accuracy: 0.9842 - val_loss: 0.1047 - val_accuracy: 0.9670
# Epoch 30/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0417 - accuracy: 0.9846 - val_loss: 0.0994 - val_accuracy: 0.9670
# Epoch 31/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0417 - accuracy: 0.9851 - val_loss: 0.1028 - val_accuracy: 0.9661
# Epoch 32/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0411 - accuracy: 0.9853 - val_loss: 0.1004 - val_accuracy: 0.9661
# Epoch 33/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0415 - accuracy: 0.9849 - val_loss: 0.1037 - val_accuracy: 0.9633
# Epoch 34/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0406 - accuracy: 0.9865 - val_loss: 0.1041 - val_accuracy: 0.9633
# Epoch 35/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0419 - accuracy: 0.9853 - val_loss: 0.1024 - val_accuracy: 0.9643
# Epoch 36/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0411 - accuracy: 0.9853 - val_loss: 0.1048 - val_accuracy: 0.9643
# Epoch 37/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0419 - accuracy: 0.9844 - val_loss: 0.1035 - val_accuracy: 0.9652
# Epoch 38/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0412 - accuracy: 0.9844 - val_loss: 0.1005 - val_accuracy: 0.9670
# Epoch 39/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0388 - accuracy: 0.9867 - val_loss: 0.1056 - val_accuracy: 0.9643
# Epoch 40/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0405 - accuracy: 0.9856 - val_loss: 0.1005 - val_accuracy: 0.9661
# Epoch 41/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0398 - accuracy: 0.9869 - val_loss: 0.1036 - val_accuracy: 0.9661
# Epoch 42/54
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0404 - accuracy: 0.9842 - val_loss: 0.1025 - val_accuracy: 0.9652
# Epoch 43/54
# 137/137 [==============================] - 1s 11ms/step - loss: 0.0407 - accuracy: 0.9846 - val_loss: 0.1010 - val_accuracy: 0.9661
# Epoch 44/54
# 137/137 [==============================] - 1s 11ms/step - loss: 0.0409 - accuracy: 0.9853 - val_loss: 0.1036 - val_accuracy: 0.9643
# Epoch 45/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0389 - accuracy: 0.9867 - val_loss: 0.1053 - val_accuracy: 0.9652
# Epoch 46/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0398 - accuracy: 0.9867 - val_loss: 0.1054 - val_accuracy: 0.9633
# Epoch 47/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0394 - accuracy: 0.9860 - val_loss: 0.1014 - val_accuracy: 0.9643
# Epoch 48/54
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0391 - accuracy: 0.9858 - val_loss: 0.1005 - val_accuracy: 0.9661
# Epoch 49/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0394 - accuracy: 0.9863 - val_loss: 0.1039 - val_accuracy: 0.9643
# Epoch 50/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.1079 - val_accuracy: 0.9670
# Epoch 51/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0404 - accuracy: 0.9863 - val_loss: 0.1043 - val_accuracy: 0.9633
# Epoch 52/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0378 - accuracy: 0.9874 - val_loss: 0.1041 - val_accuracy: 0.9643
# Epoch 53/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0392 - accuracy: 0.9863 - val_loss: 0.1050 - val_accuracy: 0.9633
# Epoch 54/54
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0402 - accuracy: 0.9851 - val_loss: 0.1037 - val_accuracy: 0.9652

# %%
eval_result = best_model.evaluate(X_test_prepared, y_test)
eval_result
# Out:
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9589
# [0.2259526252746582, 0.9589442610740662]

# %%
def plot_accuracy(history):
  plt.plot(history.history['accuracy'], label='accuracy')
  plt.plot(history.history['val_accuracy'], label='val_accuracy')
  plt.ylim([0, 1])
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)

# %%
plot_accuracy(history)

# %%
y_pred = best_model.predict(X_test_prepared).flatten()
y_pred
# Out:
# array([4.4405460e-04, 3.5664439e-04, 1.0770118e-07, ..., 1.5948284e-01,
#        2.5741756e-03, 1.7976786e-06], dtype=float32)

# %%
y_test_arr = y_test.to_numpy()
y_pred = y_pred.astype(int)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix


def plot_conf_mat(y_test, y_pred):
  fig, ax = plt.subplots(figsize=(10,7))
  ax = sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cbar=False)
  plt.xlabel("True label")
  plt.ylabel("Predicted label")

plot_conf_mat(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test_arr, y_pred)
# Out:
# 0.9626099706744868
